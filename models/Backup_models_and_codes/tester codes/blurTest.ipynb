# %%
from BlurModel import BlurRemoverModel

# %%
model_path = 'checkpoint.pth'
image_path = 'Images/Input/3.jpg'
output_save_path = 'Images/Output/3.jpg'

# %%
blur_remover = BlurRemoverModel(model_path)

# %%
output_image = blur_remover.predict(image_path)
blur_remover.display_result(image_path, output_image)
blur_remover.save_image(output_image, output_save_path)
